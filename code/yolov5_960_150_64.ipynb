# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="o48dnLAodTQCfR0VxKYJ")
project = rf.workspace("chaehyun").project("yolov5_test-ngxz1")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# /raid/coss27/yolov5
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...

# %%
# %cat /raid/coss27/yolov5_test-1/data.yaml
# Out:
# names:
# - fire
# - fire_small
# - smoke
# nc: 3
# roboflow:
#   license: CC BY 4.0
#   project: yolov5_test-ngxz1
#   url: https://universe.roboflow.com/chaehyun/yolov5_test-ngxz1/dataset/1
#   version: 1
#   workspace: chaehyun
# test: ../test/images
# train: yolov5_test-1/train/images
# val: yolov5_test-1/valid/images

# %%
# !python train.py --img 960 --epochs 150 --batch 64 --data /raid/coss27/yolov5_test-1/data.yaml --cfg /raid/coss27/yolov5/models/yolov5s.yaml --weights yolov5s.pt --name fire_smoke_results2
# Out:
# train: weights=yolov5s.pt, cfg=/raid/coss27/yolov5/models/yolov5s.yaml, data=/raid/coss27/yolov5_test-1/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=150, batch_size=64, imgsz=960, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=fire_smoke_results2, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: skipping check (offline), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 v7.0-295-gac6c4383 Python-3.8.10 torch-2.1.0a0+fe05266 CUDA:0 (NVIDIA RTX A6000, 48677MiB)
#
# ...

# %%
# %cd /raid/coss27/yolov5
# Out:
# /raid/coss27/yolov5

# %%
# !python detect.py --weights /raid/coss27/yolov5/runs/train/fire_smoke_results28/weights/best.pt --source "https://youtu.be/F_muEod1-Fo"
# Out:
# Traceback (most recent call last):
#   File "detect.py", line 46, in <module>
#     from ultralytics.utils.plotting import Annotator, colors, save_one_box
#   File "/abr/coss27/.local/lib/python3.8/site-packages/ultralytics/__init__.py", line 5, in <module>
#     from ultralytics.data.explorer.explorer import Explorer
#   File "/abr/coss27/.local/lib/python3.8/site-packages/ultralytics/data/__init__.py", line 3, in <module>
#     from .base import BaseDataset
#   File "/abr/coss27/.local/lib/python3.8/site-packages/ultralytics/data/base.py", line 12, in <module>
#     import cv2
#   File "/abr/coss27/.local/lib/python3.8/site-packages/cv2/__init__.py", line 181, in <module>
#     bootstrap()
#   File "/abr/coss27/.local/lib/python3.8/site-packages/cv2/__init__.py", line 153, in bootstrap
#     native_module = importlib.import_module("cv2")
#   File "/usr/lib/python3.8/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# ...

# %%
# !pip install opencv-contrib-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
