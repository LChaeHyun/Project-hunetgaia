# %%
from google.colab import drive
import os

drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
os.chdir('/content/drive/MyDrive/YOLOV8/')

print(os.getcwd())
# Out:
# /content/drive/MyDrive/YOLOV8

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="xBXZlxdwOzaA4ddKfbpI")
project = rf.workspace("capstone-design-2").project("fire-smoke-7rocs")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.1.41, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to fire-smoke-1 in yolov8:: 100%|██████████| 1947/1947 [00:15<00:00, 127.15it/s]

# %%
# !git clone https://github.com/ultralytics/ultralytics.git
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 23605, done.
# remote: Counting objects: 100% (634/634), done.
# remote: Compressing objects: 100% (407/407), done.
# remote: Total 23605 (delta 387), reused 390 (delta 227), pack-reused 22971
# Receiving objects: 100% (23605/23605), 14.14 MiB | 9.87 MiB/s, done.
# Resolving deltas: 100% (16475/16475), done.
# Updating files: 100% (580/580), done.

# %%
# %cd /content/drive/MyDrive/YOLOV8/ultralytics/
# Out:
# /content/drive/MyDrive/YOLOV8/ultralytics

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 744.8/744.8 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 47.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 56.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 54.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.1 MB/s eta 0:00:00
# ...

# %%
# !yolo predict
# Out:
# WARNING ⚠️ 'model' argument is missing. Using default 'model=yolov8n.pt'.
# ...
# 100% 6.23M/6.23M [00:00<00:00, 98.6MB/s]
# WARNING ⚠️ 'source' argument is missing. Using default 'source=/usr/local/lib/python3.10/dist-packages/ultralytics/assets'.
# Ultralytics YOLOv8.1.41 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/2 /usr/local/lib/python3.10/dist-packages/ultralytics/assets/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 92.3ms
# image 2/2 /usr/local/lib/python3.10/dist-packages/ultralytics/assets/zidane.jpg: 384x640 2 persons, 1 tie, 76.4ms
# Speed: 7.6ms preprocess, 84.4ms inference, 379.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cat /content/drive/MyDrive/YOLOV8/fire-smoke-1/data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
# test: ../test/images
#
# nc: 3
# names: ['fire', 'fire_small', 'smoke']
#
# roboflow:
#   workspace: capstone-design-2
#   project: fire-smoke-7rocs
#   version: 1
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/capstone-design-2/fire-smoke-7rocs/dataset/1

# %%
import yaml

with open('/content/drive/MyDrive/YOLOV8/fire-smoke-1/data.yaml', 'r') as f:
    data = yaml.load(f, Loader=yaml.SafeLoader)

data['train'] = '/content/drive/MyDrive/YOLOV8/fire-smoke-1/train/images'
data['val'] = '/content/drive/MyDrive/YOLOV8/fire-smoke-1/valid/images'

with open('/content/drive/MyDrive/YOLOV8/fire-smoke-1/data.yaml', 'w') as f:
    yaml.dump(data, f)

print(data)
# Out:
# {'names': ['fire', 'fire_small', 'smoke'], 'nc': 3, 'roboflow': {'license': 'CC BY 4.0', 'project': 'fire-smoke-7rocs', 'url': 'https://universe.roboflow.com/capstone-design-2/fire-smoke-7rocs/dataset/1', 'version': 1, 'workspace': 'capstone-design-2'}, 'test': '../test/images', 'train': '/content/drive/MyDrive/YOLOV8/fire-smoke-1/train/images', 'val': '/content/drive/MyDrive/YOLOV8/fire-smoke-1/valid/images'}

# %%
# %cd /content/drive/MyDrive/YOLOV8/ultralytics/
# Out:
# /content/drive/MyDrive/YOLOV8/ultralytics

# %%
# !pwd
# Out:
# /content/drive/MyDrive/YOLOV8/ultralytics

# %%
# !yolo detect train data='../fire-smoke-1/data.yaml' model='yolov8n.pt' epochs=100 batch=64
# Out:
# Ultralytics YOLOv8.1.41 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# %cd /content/drive/MyDrive/YOLOV8/
import shutil
shutil.make_archive('ultralytics', 'zip', './ultralytics')
# Out:
# /content/drive/MyDrive/YOLOV8
# '/content/drive/MyDrive/YOLOV8/ultralytics.zip'

# %%
# %cd /content/drive/MyDrive/YOLOV8/ultralytics/
# Out:
# /content/drive/MyDrive/YOLOV8/ultralytics

# %%
# !yolo predict source='fire.jpg' model='runs/detect/train/weights/best.pt'
# Out:
# Ultralytics YOLOv8.1.41 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/drive/MyDrive/YOLOV8/ultralytics/fire.jpg: 608x640 2 fires, 98.5ms
# Speed: 4.9ms preprocess, 98.5ms inference, 857.8ms postprocess per image at shape (1, 3, 608, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
